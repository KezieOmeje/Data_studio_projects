# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
df = pd.read_csv('NYPD_Motor_Vehicle_Collisions.csv', encoding='Latin1')
df.head()
# Out:
#          DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  06/28/2019  0:21        NaN      NaN  40.578117 -73.992645
# 1  06/28/2019  0:45        NaN      NaN  40.668266 -73.842140
# 2  06/28/2019  0:50  MANHATTAN    10034  40.861935 -73.920780
# 3  06/28/2019  1:25  MANHATTAN    10022  40.760925 -73.967050
# 4  06/28/2019  1:30        NaN      NaN  40.765250 -73.995094
#
#                   LOCATION                    ON STREET NAME  \
# 0  (40.578117, -73.992645)  NEPTUNE AVENUE
# 1   (40.668266, -73.84214)  CROSS BAY BOULEVARD
# 2   (40.861935, -73.92078)  10 AVENUE
# 3   (40.760925, -73.96705)  EAST 58 STREET
# 4   (40.76525, -73.995094)  WEST 49 STREET
#
#       CROSS STREET NAME OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                   NaN             NaN  ...                    Unspecified
# 1  SOUTH CONDUIT AVENUE             NaN  ...                    Unspecified
# 2       WEST 203 STREET             NaN  ...                    Unspecified
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
#        'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
working_data = df[['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
       'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
       'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
       'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
       'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
       'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
       'CONTRIBUTING FACTOR VEHICLE 1', 'VEHICLE TYPE CODE 1']]

# %%
working_data.head()
# Out:
#          DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  06/28/2019  0:21        NaN      NaN  40.578117 -73.992645
# 1  06/28/2019  0:45        NaN      NaN  40.668266 -73.842140
# 2  06/28/2019  0:50  MANHATTAN    10034  40.861935 -73.920780
# 3  06/28/2019  1:25  MANHATTAN    10022  40.760925 -73.967050
# 4  06/28/2019  1:30        NaN      NaN  40.765250 -73.995094
#
#                   LOCATION                    ON STREET NAME  \
# 0  (40.578117, -73.992645)  NEPTUNE AVENUE
# 1   (40.668266, -73.84214)  CROSS BAY BOULEVARD
# 2   (40.861935, -73.92078)  10 AVENUE
# 3   (40.760925, -73.96705)  EAST 58 STREET
# 4   (40.76525, -73.995094)  WEST 49 STREET
#
#       CROSS STREET NAME OFF STREET NAME  NUMBER OF PERSONS INJURED  \
# 0                   NaN             NaN                        1.0
# 1  SOUTH CONDUIT AVENUE             NaN                        0.0
# 2       WEST 203 STREET             NaN                        0.0
# ...

# %%
working_data.tail()
# Out:
#                DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1523817  07/01/2012  9:45        NaN      NaN        NaN        NaN
# 1523818  07/01/2012  9:50  MANHATTAN    10019  40.766779 -73.996762
# 1523819  07/01/2012  9:50     QUEENS    11001  40.736245 -73.702966
# 1523820  07/01/2012  9:57  MANHATTAN    10065  40.765242 -73.957868
# 1523821  07/01/2012  9:59      BRONX    10452  40.835397 -73.920305
#
#                           LOCATION                    ON STREET NAME  \
# 1523817                        NaN                               NaN
# 1523818  (40.7667789, -73.9967618)  WEST SIDE HIGHWAY
# 1523819  (40.7362448, -73.7029656)  265 STREET
# 1523820  (40.7652424, -73.9578679)  1 AVENUE
# 1523821    (40.835397, -73.920305)  EAST 167 STREET
#
#                         CROSS STREET NAME OFF STREET NAME  \
# 1523817                               NaN             NaN
# 1523818  WEST 50 STREET                               NaN
# ...

# %%
working_data['DATE'] = pd.to_datetime(working_data['DATE'])

# %%
working_data['YEAR'] = working_data['DATE'].dt.year

# %%
working_data.tail()
# Out:
#               DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1523817 2012-07-01  9:45        NaN      NaN        NaN        NaN
# 1523818 2012-07-01  9:50  MANHATTAN    10019  40.766779 -73.996762
# 1523819 2012-07-01  9:50     QUEENS    11001  40.736245 -73.702966
# 1523820 2012-07-01  9:57  MANHATTAN    10065  40.765242 -73.957868
# 1523821 2012-07-01  9:59      BRONX    10452  40.835397 -73.920305
#
#                           LOCATION                    ON STREET NAME  \
# 1523817                        NaN                               NaN
# 1523818  (40.7667789, -73.9967618)  WEST SIDE HIGHWAY
# 1523819  (40.7362448, -73.7029656)  265 STREET
# 1523820  (40.7652424, -73.9578679)  1 AVENUE
# 1523821    (40.835397, -73.920305)  EAST 167 STREET
#
#                         CROSS STREET NAME OFF STREET NAME  ...  \
# 1523817                               NaN             NaN  ...
# 1523818  WEST 50 STREET                               NaN  ...
# ...

# %%
df1 = working_data.groupby(working_data['YEAR']).sum()
df1
# Out:
#           LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# YEAR
# 2012  3.479703e+06 -6.317484e+06                    27452.0
# 2013  7.001371e+06 -1.271007e+07                    55124.0
# 2014  7.034299e+06 -1.276913e+07                    51219.0
# 2015  7.451538e+06 -1.352596e+07                    51358.0
# 2016  7.827322e+06 -1.420966e+07                    60304.0
# 2017  8.836767e+06 -1.604642e+07                    60657.0
# 2018  8.799903e+06 -1.597766e+07                    61923.0
# 2019  3.863334e+06 -7.011665e+06                    28648.0
#
#       NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# YEAR
# 2012                     137.0                           5906
# 2013                     297.0                          11988
# 2014                     262.0                          11036
# 2015                     243.0                          10084
# 2016                     245.0                          11108
# ...

# %%
df1.plot(y='NUMBER OF PERSONS KILLED', kind='barh', color = 'red')

# %%
df1.plot(y= 'NUMBER OF CYCLIST KILLED', kind = 'bar', color = 'pink')

# %%
df1.plot(y= 'NUMBER OF PEDESTRIANS KILLED', kind = 'barh')

# %%
df1.plot(y ='NUMBER OF PERSONS INJURED', kind = 'bar')

# %%
working_data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head()
# Out:
# Unspecified                       571187
# Driver Inattention/Distraction    276953
# Failure to Yield Right-of-Way      85855
# Following Too Closely              72489
# Backing Unsafely                   57672
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
working_data['VEHICLE TYPE CODE 1'].value_counts().head()
# Out:
# PASSENGER VEHICLE                      715236
# SPORT UTILITY / STATION WAGON          313499
# Sedan                                  119532
# Station Wagon/Sport Utility Vehicle     95148
# TAXI                                    50670
# Name: VEHICLE TYPE CODE 1, dtype: int64

# %%
year2019 = working_data[working_data['YEAR'] == 2019]

# %%
year2019.tail()
# Out:
#              DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 103531 2019-01-01  9:26  MANHATTAN    10128  40.779434 -73.947520
# 103532 2019-01-01  9:40        NaN      NaN  40.681503 -73.904106
# 103533 2019-01-01  9:42     QUEENS    11355  40.751610 -73.813545
# 103534 2019-01-01  9:45        NaN      NaN  40.742330 -73.837640
# 103535 2019-01-01  9:58        NaN      NaN  40.770390 -73.917710
#
#                        LOCATION                    ON STREET NAME  \
# 103531   (40.779434, -73.94752)  1 AVENUE
# 103532  (40.681503, -73.904106)  BUSHWICK AVENUE
# 103533   (40.75161, -73.813545)  LABURNUM AVENUE
# 103534    (40.74233, -73.83764)  VAN WYCK EXPWY
# 103535    (40.77039, -73.91771)  31 STREET
#
#         CROSS STREET NAME OFF STREET NAME  NUMBER OF PERSONS INJURED  \
# 103531     EAST 90 STREET             NaN                        0.0
# 103532                NaN             NaN                        0.0
# ...

# %%
year2019.to_csv('collision2019.csv', index=False)
